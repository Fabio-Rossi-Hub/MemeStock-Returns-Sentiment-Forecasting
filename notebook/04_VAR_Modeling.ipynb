# %% [markdown]
# # VAR modeling
# To assess the relationship between Wallstreetbest sentiment and stock's data, we will use VAR models.
#
# The VAR model is a statistical model for forecasting time series data. The difference between VAR and other time series models like ARIMA, ARMA or GARCH, is that VAR allows for multivariate analysis, and can also be used with exogenous variables(pretty much timeseries modeling for endogenous and common regression for exogenous).

# %%
library(tidyverse);
library(recipes);
library(caret);
library(xts);
library(MTS);
library(tseries);
library(forecast);
library(vars);
library(lmtest);
library(quantmod);

# %% [markdown]
# Before training our model we need to deal with Null values by inputing the three missing values. Since our data is sequential, and we already have few observations, I prefered not to discard the row contsining the null values.
# When fitting a VAR model we usually don't need to scale our variables so we will keep them as they are.
#
# Some of the variables are highly correlated, for example r and logr represent the same thing, so we will keep only r for the sake of interpretability, logr might come handy in the furure to fit a GARCH model.

# %%
r50 <- read.csv(file = "../data/r50_2023.csv",
                header = TRUE,
                sep = ",",
                dec = ".")

# Center and scale
recipe <-
    recipe(~., data = r50) %>%
    step_impute_mean(all_numeric()) %>%
    step_select(-c(X, timestamp)) 

recipe <- prep(recipe, training = r50)

r50_clean <- bake(recipe, r50)

heatmap(cor(r50_clean))

r50_clean <- subset(r50_clean, select = -c(logr, d_logvol))
    
r50_clean <- r50_clean[c( "r", "d_vol", "sent_avg", "sent_var", "eng_avg", "eng_var", "engsent_avg", "engsent_var")] 

cor(r50_clean)
# Out:
#             r            d_vol        sent_avg     sent_var     eng_avg
# r            1.000000000 -0.150856421 -0.074694295 -0.008354104 0.006487019
# d_vol       -0.150856421  1.000000000  0.002971014 -0.001899942 0.128256920
# sent_avg    -0.074694295  0.002971014  1.000000000 -0.727321191 0.160814468
# sent_var    -0.008354104 -0.001899942 -0.727321191  1.000000000 0.039073037
# eng_avg      0.006487019  0.128256920  0.160814468  0.039073037 1.000000000
# eng_var      0.044174035  0.077724634 -0.132881721  0.150725931 0.498057703
# engsent_avg -0.083801386  0.068473492  0.780817159 -0.520350867 0.563797089
# engsent_var  0.010591140 -0.003344306 -0.362443206  0.597085762 0.592579401
#             eng_var     engsent_avg engsent_var
# r            0.04417403 -0.08380139  0.010591140
# d_vol        0.07772463  0.06847349 -0.003344306
# sent_avg    -0.13288172  0.78081716 -0.362443206
# sent_var     0.15072593 -0.52035087  0.597085762
# eng_avg      0.49805770  0.56379709  0.592579401
# eng_var      1.00000000  0.16172549  0.572485419
# engsent_avg  0.16172549  1.00000000 -0.027475462
# engsent_var  0.57248542 -0.02747546  1.000000000
# plot without title

# %% [markdown]
# One of the key assumptions of VAR is the stationarity of the data, that is, that the time series have costant mean, costant variance and costant autocovariance. To make it simple, we don't want to have patterns or long term trends, but we want our time series to behave in a similar manner across different periods.
#
# We can assess stationarity by rejecting the null hypothesis of the Augmented Dickey-Fuller (ADF) test. In the table below we can see that all our feature are stationary, while sent_var might not be stationary. Due to the p-value we can assume that it should be stationary.

# %%
variables <- colnames(r50_clean)

adf_results <- data.frame(Variable = character(length(variables)), ADF_pValue = numeric(length(variables)))

# Perform the adf test to all variables
for (i in seq_along(variables)) {
    suppressWarnings(adf_result <- adf.test(r50_clean[[variables[i]]]))
    adf_results[i, "Variable"] <- variables[i]
    adf_results[i, "P_Value"] <- adf_result$p.value
}

# Print the variable names and p-values of adf test
head(adf_results[, c("Variable", "P_Value")],10)
# Out:
#   Variable    P_Value
# 1 r           0.01000000
# 2 d_vol       0.01000000
# 3 sent_avg    0.01437974
# 4 sent_var    0.05703999
# 5 eng_avg     0.02047366
# 6 eng_var     0.01000000
# 7 engsent_avg 0.01000000
# 8 engsent_var 0.01000000

# %% [markdown]
# Once we have checked that the time series respect the model assumptions we can prepare the dataset fot training and testing. We will have different datasets for VAR and VARX, this because VARX needs an additional dataset input for exogenolus variables, that will be treated like normal estimators, without taking into account their lag. In orderot explore the impact of sentiment we will analyse it both as endogenous and as exogenous variables.

# %%
# Train/Test split
idx <- round(nrow(r50_clean) * 0.9)

df_train <- head(r50_clean, idx) %>% na.omit()
df_test <- tail(r50_clean,
            nrow(r50_clean) - idx) %>%
            na.omit()

# Set r and d_vol as endogenous variables
endogenous <- c("r", "d_vol")

# Set sentiment variables as exogenous
exogenous <- c("sent_avg", "eng_var")

# VARX Exogenous
df_ex_train <- df_train[exogenous]
df_ex_test <- df_test[exogenous] 

# VARX Endogenous
df_end_train <- df_train[endogenous]
df_end_test <- df_test[endogenous]

# %% [markdown]
# Now that we have our training data, we can find the optimal number of lags to fit our model. VARoder and VARoderI both provide an insight on which is the best number of lags, with the first one using statistical tests, the latter using impulse response functions.
#
# VARselect and VARorderI both suggest that past observations are not meaningful predictors for future observations, and that the vriables are not interdependent. Using a lag of 0 would suggest that the model will be a simple linear regression.
#
# We will keep this in mind but we will use the 10 lags suggested by AIC to confirm our assumption.

# %%
# Lag selection for VAR
VARorder(df_train, 10)
VARorderI(df_train, 10)

# Lag selection for VARX
VARselect(df_end_train, exogen = df_ex_train)
# Out:
# selected order: aic =  10
# selected order: bic =  0
# selected order: hq =  0
# Summary table:
#        p     AIC     BIC     HQ    M(p) p-value
#  [1,]  0  3.3510  3.3510 3.3510  0.0000  0.0000
#  [2,]  1  3.5090  5.0892 4.1498 90.9621  0.0150
#  [3,]  2  3.8364  6.9969 5.1181 69.0192  0.3117
#  [4,]  3  4.0967  8.8375 6.0193 67.1796  0.3687
#  [5,]  4  4.4013 10.7223 6.9647 56.9666  0.7212
#  [6,]  5  4.2879 12.1891 7.4921 74.0443  0.1831
#  [7,]  6  4.2770 13.7585 8.1221 58.6669  0.6649
#  [8,]  7  3.8836 14.9453 8.3696 65.0600  0.4396
#  [9,]  8  2.9072 15.5492 8.0340 72.0486  0.2291
# [10,]  9  1.5572 15.7793 7.3248 64.3715  0.4635
# [11,] 10 -1.7292 14.0732 4.6792 78.0629  0.1112
# selected order: aic =  10
# selected order: bic =  0
# selected order: hq =  0
# M statistic and its p-value
#        Mstat        pv
#  [1,] 125.53 6.915e-06
#  [2,]  70.17 2.786e-01
#  [3,]  63.15 5.065e-01
#  [4,]  49.03 9.167e-01
#  [5,]  79.39 9.310e-02
#  [6,]  54.94 7.831e-01
#  [7,]  66.03 4.065e-01
#  [8,]  72.36 2.215e-01
#  [9,]  71.11 2.529e-01
# [10,]  79.59 9.050e-02
# Summary table:
#        p      AIC     BIC     HQ    M(p)    p-value
#  [1,]  0  3.97721  3.9772 3.9772   0.000 0.0000e+00
#  [2,]  1  3.75984  5.3492 4.4043 125.529 6.9153e-06
#  [3,]  2  4.10622  7.3036 5.4024  70.168 2.7858e-01
#  [4,]  3  4.47713  9.3015 6.4325  63.152 5.0648e-01
#  [5,]  4  4.98214 11.4528 7.6042  49.029 9.1668e-01
#  [6,]  5  4.87918 13.0158 8.1756  79.385 9.3099e-02
#  [7,]  6  5.07180 14.8945 9.0503  54.937 7.8307e-01
#  [8,]  7  4.80869 16.3380 9.4773  66.031 4.0652e-01
#  [9,]  8  4.00311 17.2600 9.3699  72.356 2.2153e-01
# [10,]  9  2.59572 17.6015 8.6688  71.114 2.5292e-01
# [11,] 10 -0.54307 16.2335 6.2447  79.592 9.0500e-02
# $selection
# AIC(n)  HQ(n)  SC(n) FPE(n)
#      1      1      1      1
#
# $criteria
#                    1             2             3             4             5
# AIC(n) -1.130106e+01 -1.127729e+01 -1.122933e+01 -1.122768e+01 -1.126057e+01
# HQ(n)  -1.119500e+01 -1.112880e+01 -1.103843e+01 -1.099435e+01 -1.098481e+01
# SC(n)  -1.103893e+01 -1.091030e+01 -1.075749e+01 -1.065099e+01 -1.057902e+01
# FPE(n)  1.236193e-05  1.266315e-05  1.329228e-05  1.332538e-05  1.290988e-05
#                    6             7             8             9            10
# AIC(n) -1.126118e+01 -1.127864e+01 -1.126263e+01 -1.126261e+01 -1.119967e+01
# HQ(n)  -1.094301e+01 -1.091804e+01 -1.085960e+01 -1.081716e+01 -1.071179e+01
# SC(n)  -1.047478e+01 -1.038739e+01 -1.026652e+01 -1.016165e+01 -9.993853e+00
# FPE(n)  1.292325e-05  1.272722e-05  1.296849e-05  1.301338e-05  1.391722e-05

# %% [markdown]
# Our first VAR model will have a ton of variables, because each of the lags of each feature will be a variable itself. So to reduce complexity we will just remove the variables whose coefficients have a p-value smaller than 0.05 and we will re-fit the model accordingly. Once we refined our model we can then check how returns are affected by sudden changes in sentiment.
#
# However, we need to be careful when assessing the predictive power of our variables, as having many lags can lead to false positives and high autocorrelation. As we can see from the residuals some of our variables are highly autocorrelated.

# %%
var_1 <- VAR(df_train, p = 10)

var_2 <- restrict(var_1,thresh = 2)
summary(var_2)

var_irf <- irf(var_2, response = "r")
plot(var_irf)
# Out:
# VAR Estimation Results:
# =========================
# Endogenous variables: r, d_vol, sent_avg, sent_var, eng_avg, eng_var, engsent_avg, engsent_var
# Deterministic variables: const
# Sample size: 99
# Log Likelihood: -1108.987
# Roots of the characteristic polynomial:
# 1.119 1.119 1.066 1.059 1.059 1.054 1.005 1.005 1.004 1.004 0.9955 0.9955 0.9845 0.9845 0.961 0.961 0.9595 0.9595 0.9584 0.9584 0.9545 0.9545 0.9534 0.9534 0.952 0.952 0.9515 0.9515 0.9496 0.9496 0.9449 0.9449 0.9438 0.9438 0.9425 0.9425 0.9351 0.9351 0.9263 0.9263 0.9237 0.9237 0.916 0.916 0.9123 0.9123 0.9096 0.8964 0.8964 0.8916 0.8916 0.8907 0.8905 0.8905 0.8867 0.8867 0.8847 0.8847 0.8446 0.8446 0.8398 0.8398 0.8134 0.8134 0.7935 0.7531 0.7531 0.7328 0.7328 0.7309 0.7309 0.6207 0.6207 0.272 0.2627 0.2627 2.712e-15     0     0     0
# Call:
# VAR(y = df_train, p = 10)
#
#
# Estimation results for equation r:
# ==================================
# r = r.l1 + sent_var.l2 + eng_avg.l2 + engsent_avg.l2 + sent_var.l3 + eng_var.l3 + engsent_var.l3 + d_vol.l4 + sent_avg.l5 + d_vol.l7 + r.l8 + sent_avg.l8 + sent_var.l8 + eng_avg.l10
#
#                  Estimate Std. Error t value Pr(>|t|)
# r.l1           -3.497e-01  9.370e-02  -3.732 0.000342 ***
# sent_var.l2    -3.051e-02  1.214e-02  -2.512 0.013879 *
# eng_avg.l2      1.820e-03  4.285e-04   4.248 5.49e-05 ***
# engsent_avg.l2 -2.044e-03  5.163e-04  -3.958 0.000156 ***
# sent_var.l3    -2.708e-02  1.338e-02  -2.024 0.046144 *
# eng_var.l3     -4.208e-05  1.600e-05  -2.629 0.010160 *
# engsent_var.l3  3.740e-05  1.490e-05   2.510 0.013976 *
# d_vol.l4        2.975e-02  8.593e-03   3.463 0.000840 ***
# sent_avg.l5     3.611e-02  1.204e-02   3.000 0.003544 **
# d_vol.l7       -3.383e-02  8.387e-03  -4.034 0.000119 ***
# r.l8           -3.642e-01  1.019e-01  -3.575 0.000581 ***
# sent_avg.l8    -3.954e-02  1.337e-02  -2.958 0.004010 **
# sent_var.l8    -4.215e-02  1.261e-02  -3.342 0.001240 **
# eng_avg.l10     5.003e-04  2.397e-04   2.087 0.039869 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 0.01479 on 85 degrees of freedom
# Multiple R-Squared: 0.3576,	Adjusted R-squared: 0.2518
# F-statistic:  3.38 on 14 and 85 DF,  p-value: 0.0002428
#
#
# Estimation results for equation d_vol:
# ======================================
# d_vol = eng_var.l1 + engsent_var.l1 + d_vol.l2 + eng_avg.l2 + eng_var.l2 + d_vol.l4 + engsent_var.l4 + r.l5 + eng_avg.l5 + engsent_avg.l5 + engsent_var.l6 + d_vol.l7 + sent_avg.l7 + eng_avg.l7 + eng_var.l7 + d_vol.l8 + sent_avg.l8 + sent_var.l8 + sent_avg.l9 + sent_avg.l10 + eng_var.l10 + const
#
#                  Estimate Std. Error t value Pr(>|t|)
# eng_var.l1     -4.013e-04  1.564e-04  -2.566 0.012225 *
# engsent_var.l1  2.605e-04  9.973e-05   2.612 0.010830 *
# d_vol.l2       -2.687e-01  7.898e-02  -3.402 0.001064 **
# eng_avg.l2      1.069e-02  3.550e-03   3.010 0.003536 **
# eng_var.l2     -5.213e-04  1.377e-04  -3.786 0.000302 ***
# d_vol.l4       -2.468e-01  7.871e-02  -3.136 0.002426 **
# engsent_var.l4 -1.838e-04  7.641e-05  -2.406 0.018548 *
# r.l5           -2.370e+00  8.564e-01  -2.767 0.007078 **
# eng_avg.l5      7.757e-03  3.306e-03   2.346 0.021548 *
# engsent_avg.l5 -7.558e-03  3.404e-03  -2.220 0.029341 *
# engsent_var.l6  2.207e-04  8.140e-05   2.712 0.008251 **
# d_vol.l7        3.158e-01  8.035e-02   3.931 0.000184 ***
# sent_avg.l7     3.183e-01  1.076e-01   2.958 0.004113 **
# eng_avg.l7     -9.556e-03  3.283e-03  -2.911 0.004711 **
# eng_var.l7      5.477e-04  1.502e-04   3.647 0.000480 ***
# d_vol.l8        1.881e-01  7.636e-02   2.463 0.016006 *
# sent_avg.l8     6.681e-01  1.739e-01   3.841 0.000250 ***
# sent_var.l8     7.702e-01  1.566e-01   4.918 4.85e-06 ***
# sent_avg.l9     4.030e-01  1.166e-01   3.455 0.000898 ***
# sent_avg.l10   -4.723e-01  1.152e-01  -4.099 0.000102 ***
# eng_var.l10     3.924e-04  1.303e-04   3.011 0.003519 **
# const          -9.483e-01  2.123e-01  -4.467 2.68e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 0.1368 on 77 degrees of freedom
# Multiple R-Squared: 0.6146,	Adjusted R-squared: 0.5044
# F-statistic:  5.58 on 22 and 77 DF,  p-value: 7.655e-09
#
#
# Estimation results for equation sent_avg:
# =========================================
# sent_avg = sent_avg.l1 + engsent_var.l1 + d_vol.l2 + sent_var.l2 + eng_avg.l2 + engsent_var.l2 + r.l3 + r.l4 + sent_avg.l5 + engsent_var.l5 + sent_avg.l6 + eng_avg.l6 + engsent_var.l6 + d_vol.l7 + sent_avg.l7 + eng_avg.l7 + engsent_avg.l7 + engsent_var.l8 + d_vol.l9
#
#                  Estimate Std. Error t value Pr(>|t|)
# sent_avg.l1     3.162e-01  8.597e-02   3.678 0.000424 ***
# engsent_var.l1  1.643e-04  6.978e-05   2.354 0.021009 *
# d_vol.l2        1.553e-01  5.915e-02   2.626 0.010346 *
# sent_var.l2    -3.383e-01  1.055e-01  -3.206 0.001934 **
# eng_avg.l2     -9.821e-03  3.094e-03  -3.174 0.002132 **
# engsent_var.l2  3.158e-04  1.228e-04   2.571 0.011981 *
# r.l3            2.500e+00  6.741e-01   3.709 0.000382 ***
# r.l4            1.519e+00  6.959e-01   2.182 0.032037 *
# sent_avg.l5     5.600e-01  9.845e-02   5.688 2.03e-07 ***
# engsent_var.l5  2.493e-04  6.834e-05   3.647 0.000470 ***
# sent_avg.l6    -4.037e-01  1.034e-01  -3.903 0.000197 ***
# eng_avg.l6      1.126e-02  2.975e-03   3.786 0.000295 ***
# engsent_var.l6 -5.423e-04  9.624e-05  -5.634 2.54e-07 ***
# d_vol.l7       -1.618e-01  6.312e-02  -2.564 0.012228 *
# sent_avg.l7     6.037e-01  1.485e-01   4.066 0.000111 ***
# eng_avg.l7      9.359e-03  2.878e-03   3.252 0.001677 **
# engsent_avg.l7 -2.359e-02  4.785e-03  -4.929 4.40e-06 ***
# engsent_var.l8  1.519e-04  6.152e-05   2.469 0.015695 *
# d_vol.l9        1.422e-01  6.290e-02   2.261 0.026481 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 0.1084 on 80 degrees of freedom
# Multiple R-Squared: 0.9717,	Adjusted R-squared: 0.9649
# F-statistic: 144.4 on 19 and 80 DF,  p-value: < 2.2e-16
#
#
# Estimation results for equation sent_var:
# =========================================
# sent_var = d_vol.l1 + eng_var.l1 + sent_var.l2 + eng_avg.l2 + eng_var.l2 + engsent_var.l2 + r.l3 + d_vol.l3 + sent_avg.l3 + sent_var.l3 + eng_avg.l3 + engsent_avg.l3 + engsent_var.l3 + r.l4 + sent_var.l4 + eng_avg.l4 + engsent_var.l4 + sent_avg.l5 + sent_var.l5 + sent_var.l6 + eng_avg.l6 + engsent_var.l6 + d_vol.l7 + sent_avg.l7 + eng_avg.l7 + engsent_avg.l7 + engsent_var.l8 + r.l9 + d_vol.l9 + sent_avg.l9 + sent_var.l9 + engsent_avg.l9 + sent_avg.l10 + eng_avg.l10 + engsent_avg.l10 + const
#
#                   Estimate Std. Error t value Pr(>|t|)
# d_vol.l1         2.113e-01  8.371e-02   2.524 0.014140 *
# eng_var.l1      -3.574e-04  1.493e-04  -2.394 0.019660 *
# sent_var.l2      6.413e-01  1.696e-01   3.781 0.000350 ***
# eng_avg.l2       1.714e-02  4.808e-03   3.565 0.000702 ***
# eng_var.l2       4.583e-04  1.707e-04   2.684 0.009276 **
# engsent_var.l2  -8.295e-04  2.003e-04  -4.140 0.000105 ***
# r.l3            -4.778e+00  9.032e-01  -5.290 1.64e-06 ***
# d_vol.l3        -2.890e-01  8.632e-02  -3.348 0.001377 **
# sent_avg.l3     -7.324e-01  2.642e-01  -2.772 0.007320 **
# sent_var.l3     -4.194e-01  1.936e-01  -2.166 0.034109 *
# eng_avg.l3      -3.115e-02  7.056e-03  -4.414 4.05e-05 ***
# engsent_avg.l3   2.510e-02  7.278e-03   3.449 0.001009 **
# engsent_var.l3   4.276e-04  1.732e-04   2.469 0.016275 *
# r.l4            -2.795e+00  8.834e-01  -3.164 0.002397 **
# sent_var.l4      6.309e-01  1.664e-01   3.790 0.000339 ***
# eng_avg.l4       1.957e-02  5.391e-03   3.631 0.000568 ***
# engsent_var.l4  -8.407e-04  1.952e-04  -4.308 5.89e-05 ***
# sent_avg.l5     -1.122e+00  2.030e-01  -5.526 6.67e-07 ***
# sent_var.l5     -4.073e-01  1.544e-01  -2.637 0.010515 *
# sent_var.l6     -5.020e-01  1.844e-01  -2.722 0.008377 **
# eng_avg.l6      -2.637e-02  5.249e-03  -5.024 4.44e-06 ***
# engsent_var.l6   9.605e-04  2.012e-04   4.774 1.11e-05 ***
# d_vol.l7         3.116e-01  8.815e-02   3.535 0.000771 ***
# sent_avg.l7     -1.098e+00  2.562e-01  -4.285 6.37e-05 ***
# eng_avg.l7      -2.459e-02  4.986e-03  -4.932 6.26e-06 ***
# engsent_avg.l7   5.017e-02  8.391e-03   5.979 1.15e-07 ***
# engsent_var.l8  -1.744e-04  8.393e-05  -2.077 0.041857 *
# r.l9             3.392e+00  1.071e+00   3.168 0.002370 **
# d_vol.l9        -1.891e-01  8.329e-02  -2.270 0.026628 *
# sent_avg.l9      5.169e-01  2.144e-01   2.411 0.018817 *
# sent_var.l9     -3.594e-01  1.577e-01  -2.279 0.026093 *
# engsent_avg.l9  -1.434e-02  5.222e-03  -2.746 0.007852 **
# sent_avg.l10    -8.406e-01  2.687e-01  -3.128 0.002661 **
# eng_avg.l10     -1.018e-02  4.178e-03  -2.437 0.017649 *
# engsent_avg.l10  2.166e-02  9.091e-03   2.383 0.020200 *
# const            2.619e+00  4.125e-01   6.349 2.68e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 0.1275 on 63 degrees of freedom
# Multiple R-Squared: 0.9155,	Adjusted R-squared: 0.8672
# F-statistic: 18.96 on 36 and 63 DF,  p-value: < 2.2e-16
#
#
# Estimation results for equation eng_avg:
# ========================================
# eng_avg = r.l1 + sent_var.l1 + engsent_avg.l1 + engsent_var.l1 + r.l2 + d_vol.l2 + sent_var.l2 + d_vol.l3 + eng_avg.l3 + d_vol.l4 + sent_avg.l4 + sent_var.l4 + engsent_var.l4 + d_vol.l5 + sent_avg.l5 + eng_avg.l5 + eng_var.l5 + engsent_avg.l5 + r.l6 + d_vol.l6 + sent_avg.l6 + r.l7 + d_vol.l7 + sent_avg.l7 + engsent_avg.l7 + engsent_var.l7 + r.l8 + eng_avg.l8 + eng_var.l8 + engsent_avg.l8 + r.l9 + sent_avg.l9 + engsent_avg.l9 + engsent_var.l9 + d_vol.l10 + sent_avg.l10 + eng_var.l10 + engsent_avg.l10 + const
#
#                   Estimate Std. Error t value Pr(>|t|)
# r.l1             75.220010  24.086999   3.123 0.002756 **
# sent_var.l1      24.885592   4.458708   5.581 6.07e-07 ***
# engsent_avg.l1    0.478613   0.112078   4.270 7.06e-05 ***
# engsent_var.l1   -0.015102   0.003755  -4.022 0.000164 ***
# r.l2             61.169355  24.474008   2.499 0.015196 *
# d_vol.l2         -8.302848   2.475988  -3.353 0.001387 **
# sent_var.l2       8.249855   2.366841   3.486 0.000924 ***
# d_vol.l3         -8.550509   2.158193  -3.962 0.000200 ***
# eng_avg.l3       -0.358129   0.092079  -3.889 0.000254 ***
# d_vol.l4         -9.320097   2.274235  -4.098 0.000127 ***
# sent_avg.l4     -24.898852   5.053679  -4.927 6.90e-06 ***
# sent_var.l4     -12.415571   4.233859  -2.932 0.004755 **
# engsent_var.l4   -0.007054   0.003028  -2.330 0.023211 *
# d_vol.l5        -12.970243   2.429614  -5.338 1.51e-06 ***
# sent_avg.l5      16.999981   7.115927   2.389 0.020055 *
# eng_avg.l5        0.570854   0.131674   4.335 5.65e-05 ***
# eng_var.l5       -0.009278   0.004127  -2.248 0.028257 *
# engsent_avg.l5   -0.669337   0.209956  -3.188 0.002277 **
# r.l6            -58.408981  22.954815  -2.545 0.013534 *
# d_vol.l6         -9.654872   2.270542  -4.252 7.52e-05 ***
# sent_avg.l6     -10.343723   3.360694  -3.078 0.003141 **
# r.l7            -66.808703  24.975386  -2.675 0.009617 **
# d_vol.l7         -9.117230   2.409764  -3.783 0.000359 ***
# sent_avg.l7     -18.560517   6.021731  -3.082 0.003101 **
# engsent_avg.l7    0.361982   0.141665   2.555 0.013166 *
# engsent_var.l7   -0.007794   0.002600  -2.998 0.003953 **
# r.l8             71.831909  26.014017   2.761 0.007628 **
# eng_avg.l8        0.425396   0.101252   4.201 8.94e-05 ***
# eng_var.l8       -0.018983   0.004464  -4.252 7.52e-05 ***
# engsent_avg.l8   -0.584013   0.093344  -6.257 4.56e-08 ***
# r.l9            122.194758  25.627931   4.768 1.23e-05 ***
# sent_avg.l9      34.890902   6.694309   5.212 2.42e-06 ***
# engsent_avg.l9   -1.086158   0.170179  -6.382 2.80e-08 ***
# engsent_var.l9    0.012218   0.002677   4.564 2.54e-05 ***
# d_vol.l10         7.122886   2.113189   3.371 0.001316 **
# sent_avg.l10     11.820786   5.512391   2.144 0.036061 *
# eng_var.l10       0.008626   0.003911   2.206 0.031260 *
# engsent_avg.l10  -0.404716   0.172352  -2.348 0.022178 *
# const            34.909775   7.354718   4.747 1.32e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 3.214 on 60 degrees of freedom
# Multiple R-Squared: 0.9905,	Adjusted R-squared: 0.9843
# F-statistic: 160.2 on 39 and 60 DF,  p-value: < 2.2e-16
#
#
# Estimation results for equation eng_var:
# ========================================
# eng_var = sent_avg.l1 + eng_avg.l1 + sent_avg.l2 + eng_var.l2 + engsent_avg.l2 + engsent_avg.l7 + r.l8 + engsent_avg.l8 + d_vol.l10 + eng_avg.l10
#
#                  Estimate Std. Error t value Pr(>|t|)
# sent_avg.l1    -200.18447   59.26408  -3.378 0.001085 **
# eng_avg.l1       10.94746    1.35835   8.059 3.28e-12 ***
# sent_avg.l2     316.79286   99.93415   3.170 0.002091 **
# eng_var.l2        0.27244    0.07737   3.521 0.000680 ***
# engsent_avg.l2  -14.86017    2.91339  -5.101 1.90e-06 ***
# engsent_avg.l7    3.53866    1.70333   2.077 0.040637 *
# r.l8           1832.88238  526.99137   3.478 0.000784 ***
# engsent_avg.l8   -7.90878    1.86788  -4.234 5.57e-05 ***
# d_vol.l10       119.70319   48.41009   2.473 0.015310 *
# eng_avg.l10       4.30273    1.27479   3.375 0.001094 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 88.35 on 89 degrees of freedom
# Multiple R-Squared: 0.9143,	Adjusted R-squared: 0.9046
# F-statistic: 94.89 on 10 and 89 DF,  p-value: < 2.2e-16
#
#
# Estimation results for equation engsent_avg:
# ============================================
# engsent_avg = sent_avg.l1 + engsent_var.l1 + r.l3 + d_vol.l4 + eng_var.l4 + r.l5 + sent_avg.l5 + eng_var.l5 + engsent_var.l5 + eng_avg.l6 + engsent_avg.l6 + engsent_var.l6 + d_vol.l7 + engsent_avg.l7 + eng_avg.l9 + engsent_var.l9 + sent_avg.l10 + eng_avg.l10 + engsent_avg.l10
#
#                  Estimate Std. Error t value Pr(>|t|)
# sent_avg.l1      7.090352   2.756067   2.573 0.011941 *
# engsent_var.l1   0.005070   0.002241   2.262 0.026379 *
# r.l3            61.113859  24.410481   2.504 0.014329 *
# d_vol.l4        -6.965307   2.251206  -3.094 0.002720 **
# eng_var.l4      -0.011603   0.003669  -3.162 0.002211 **
# r.l5            55.906070  24.239717   2.306 0.023677 *
# sent_avg.l5     13.706593   3.574020   3.835 0.000249 ***
# eng_var.l5      -0.015223   0.004797  -3.173 0.002138 **
# engsent_var.l5   0.010882   0.003180   3.422 0.000983 ***
# eng_avg.l6       0.694095   0.154044   4.506 2.23e-05 ***
# engsent_avg.l6  -0.642304   0.125490  -5.118 2.08e-06 ***
# engsent_var.l6  -0.019360   0.003826  -5.060 2.62e-06 ***
# d_vol.l7        -5.704209   2.217712  -2.572 0.011958 *
# engsent_avg.l7  -0.276528   0.093940  -2.944 0.004244 **
# eng_avg.l9      -0.376099   0.098005  -3.838 0.000247 ***
# engsent_var.l9   0.011713   0.002938   3.986 0.000147 ***
# sent_avg.l10    20.331654   6.044661   3.364 0.001183 **
# eng_avg.l10      0.371829   0.104862   3.546 0.000657 ***
# engsent_avg.l10 -0.687989   0.207686  -3.313 0.001389 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 3.979 on 80 degrees of freedom
# Multiple R-Squared: 0.9408,	Adjusted R-squared: 0.9267
# F-statistic: 66.91 on 19 and 80 DF,  p-value: < 2.2e-16
#
#
# Estimation results for equation engsent_var:
# ============================================
# engsent_var = r.l3 + d_vol.l3 + sent_avg.l3 + eng_avg.l3 + engsent_avg.l3 + eng_avg.l6 + engsent_var.l6 + sent_avg.l7 + eng_avg.l7 + engsent_avg.l7 + r.l9 + eng_var.l9 + const
#
#                  Estimate Std. Error t value Pr(>|t|)
# r.l3           -2714.3145   884.5003  -3.069  0.00288 **
# d_vol.l3        -182.5449    78.5696  -2.323  0.02252 *
# sent_avg.l3    -1003.8450   222.1526  -4.519 1.97e-05 ***
# eng_avg.l3       -13.5282     4.8113  -2.812  0.00610 **
# engsent_avg.l3    21.3867     7.1935   2.973  0.00382 **
# eng_avg.l6       -14.0424     3.4850  -4.029  0.00012 ***
# engsent_var.l6     0.2083     0.1007   2.069  0.04154 *
# sent_avg.l7     -698.2537   217.6682  -3.208  0.00188 **
# eng_avg.l7       -13.6134     4.4756  -3.042  0.00312 **
# engsent_avg.l7    23.2652     7.0527   3.299  0.00141 **
# r.l9            2027.2433   902.2793   2.247  0.02721 *
# eng_var.l9        -0.3180     0.1185  -2.683  0.00875 **
# const           1710.1889   203.7031   8.395 8.36e-13 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 142.4 on 86 degrees of freedom
# Multiple R-Squared: 0.8777,	Adjusted R-squared: 0.8592
# F-statistic: 47.46 on 13 and 86 DF,  p-value: < 2.2e-16
#
#
#
# Covariance matrix of residuals:
#                      r     d_vol   sent_avg   sent_var   eng_avg    eng_var
# r            0.0010321 -0.001452  -0.001316  0.0004596  -0.01380    -0.4821
# d_vol       -0.0014523  0.080020   0.001468  0.0052090   0.06457    -2.4502
# sent_avg    -0.0013156  0.001468   0.052196 -0.0274280   0.04511     8.1447
# sent_var     0.0004596  0.005209  -0.027428  0.0568830   0.03668    -1.5800
# eng_avg     -0.0138025  0.064571   0.045109  0.0366794  34.43107   139.0644
# eng_var     -0.4821378 -2.450225   8.144675 -1.5800349 139.06439 38595.5196
# engsent_avg -0.0393106  0.207580   1.161335 -0.7762548   9.36451   123.9339
# engsent_var  0.5717290  0.539808 -13.753712 24.9736055 422.60288 19256.0927
#             engsent_avg engsent_var
# r              -0.03931      0.5717
# d_vol           0.20758      0.5398
# sent_avg        1.16134    -13.7537
# sent_var       -0.77625     24.9736
# eng_avg         9.36451    422.6029
# eng_var       123.93387  19256.0927
# engsent_avg    70.36011   -282.9258
# engsent_var  -282.92578  96871.7883
#
# Correlation matrix of residuals:
#                    r     d_vol sent_avg sent_var  eng_avg  eng_var engsent_avg
# r            1.00000 -0.159805 -0.17925  0.05998 -0.07322 -0.07639    -0.14588
# d_vol       -0.15980  1.000000  0.02272  0.07721  0.03890 -0.04409     0.08748
# sent_avg    -0.17925  0.022721  1.00000 -0.50337  0.03365  0.18146     0.60601
# sent_var     0.05998  0.077209 -0.50337  1.00000  0.02621 -0.03372    -0.38802
# eng_avg     -0.07322  0.038901  0.03365  0.02621  1.00000  0.12063     0.19026
# eng_var     -0.07639 -0.044090  0.18146 -0.03372  0.12063  1.00000     0.07521
# engsent_avg -0.14588  0.087483  0.60601 -0.38802  0.19026  0.07521     1.00000
# engsent_var  0.05718  0.006131 -0.19342  0.33643  0.23140  0.31492    -0.10837
#             engsent_var
# r              0.057179
# d_vol          0.006131
# sent_avg      -0.193421
# sent_var       0.336427
# eng_avg        0.231397
# eng_var        0.314921
# engsent_avg   -0.108370
# engsent_var    1.000000

# %%
#VARX model---------------

x1 <- VAR(df_end_train, 7, exogen = df_ex_train)

x2 <- restrict(x1, method = "ser")
summary(x2)
# Out:
# VAR Estimation Results:
# =========================
# Endogenous variables: r, d_vol
# Deterministic variables: const
# Sample size: 102
# Log Likelihood: 307.852
# Roots of the characteristic polynomial:
# 0.8289 0.8289 0.8238 0.8238 0.8049 0.8025 0.8025 0.7651 0.7651 0.7277 0.7277 0.6611     0     0
# Call:
# VAR(y = df_end_train, p = 7, exogen = df_ex_train)
#
#
# Estimation results for equation r:
# ==================================
# r = r.l5 + d_vol.l7
#
#           Estimate Std. Error t value Pr(>|t|)
# r.l5     -0.215740   0.094459  -2.284   0.0245 *
# d_vol.l7 -0.021266   0.008211  -2.590   0.0110 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 0.01617 on 100 degrees of freedom
# Multiple R-Squared: 0.1022,	Adjusted R-squared: 0.08425
# F-statistic: 5.692 on 2 and 100 DF,  p-value: 0.004559
#
#
# Estimation results for equation d_vol:
# ======================================
# d_vol = d_vol.l2 + d_vol.l4 + r.l5
#
#          Estimate Std. Error t value Pr(>|t|)
# d_vol.l2 -0.22925    0.09673  -2.370   0.0197 *
# d_vol.l4 -0.21010    0.09647  -2.178   0.0318 *
# r.l5     -2.32907    1.08223  -2.152   0.0338 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# Residual standard error: 0.1847 on 99 degrees of freedom
# Multiple R-Squared: 0.1201,	Adjusted R-squared: 0.09339
# F-statistic: 4.502 on 3 and 99 DF,  p-value: 0.005271
#
#
#
# Covariance matrix of residuals:
#                r      d_vol
# r      0.0003076 -0.0006555
# d_vol -0.0006555  0.0391061
#
# Correlation matrix of residuals:
#            r  d_vol
# r      1.000 -0.189
# d_vol -0.189  1.000

# %% [markdown]
# The final step of our research is to perform a Granger Causality test to assess whether the sentiment of WallStreetBets SubReddit really had a causal effect on returns. The granger Test basically tells us if using the lags of one variable leads to a better forcasting of another one.
#
# The Granger Test's results clearly show that there is indeed a causal effect between sentiment and returns, but the high correlation between residuals indicates that the model is overfitted, and won't be able to accurately predict future returns of the R50 index.

# %%
# Perform Granger causality test between engagement and other variables
granger_test_result <- causality(var_1, cause = "engsent_avg",boot = TRUE)
print(granger_test_result)
# Out:
# $Granger
#
# 	Granger causality H0: r do not Granger-cause d_vol sent_avg sent_var
# 	eng_avg eng_var engsent_avg engsent_var
#
# data:  VAR object var_1
# F-Test = 1.5982, boot.runs = 100, p-value < 2.2e-16
#
#
# $Instant
#
# 	H0: No instantaneous causality between: r and d_vol sent_avg sent_var
# 	eng_avg eng_var engsent_avg engsent_var
#
# data:  VAR object var_1
# Chi-squared = 35.921, df = 7, p-value = 7.501e-06
